# %% [markdown]
# <h1>This is Notebook</h1>

# %%
count = 1
while count < 11:
    print(f"5*{count}= {5*count}")
    count +=1

# %%
for i in range(1, 11):
    print(f"5*{i} = {5*i}")

# %% [markdown]
# Now python greet function

# %%
print("Hello Students..!")
# Out:
# Hello Students..!
